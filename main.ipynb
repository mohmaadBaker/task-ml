# %%
import pandas as pd

# %%
data=pd.read_csv('imdb_top_1000.csv')
data
# Out:
#                                            Poster_Link
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...  \
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime
# 0    The Shawshank Redemption          1994           A  142 min  \
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
print(data.columns)
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
# col=['Meta_score']
# data.drop(columns=col, inplace=True)

# %%
genre_counts = data['Genre'].value_counts()

# Print the genre counts
print(genre_counts)
# Out:
# Genre
# Drama                        85
# Drama, Romance               37
# Comedy, Drama                35
# Comedy, Drama, Romance       31
# Action, Crime, Drama         30
#                              ..
# Adventure, Thriller           1
# Animation, Action, Sci-Fi     1
# Action, Crime, Comedy         1
# Animation, Crime, Mystery     1
# Adventure, Comedy, War        1
# Name: count, Length: 202, dtype: int64

# %%
genre_counts = data['Genre'].value_counts()

# Create a new dataframe from the genre counts
genre_counts_df = pd.DataFrame({'Genre': genre_counts.index, 'Count': genre_counts.values})
print(genre_counts_df)
# Out:
#                          Genre  Count
# 0                        Drama     85
# 1               Drama, Romance     37
# 2                Comedy, Drama     35
# 3       Comedy, Drama, Romance     31
# 4         Action, Crime, Drama     30
# ..                         ...    ...
# 197        Adventure, Thriller      1
# 198  Animation, Action, Sci-Fi      1
# 199      Action, Crime, Comedy      1
# 200  Animation, Crime, Mystery      1
# 201     Adventure, Comedy, War      1
#
# [202 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
genre_counts = data['Genre'].value_counts()
genre_counts_df = pd.DataFrame({'Genre': genre_counts.index, 'Count': genre_counts.values})
genre_counts_df = genre_counts_df.sort_values(by='Count', ascending=False)
genre_counts_df.plot(x='Genre', y='Count', kind='bar', legend=False)

# Set the labels and title
plt.xlabel('Genre')
plt.ylabel('Count')
plt.title('Count of Movies/TV Shows in Each Genre')

# Show the plot
plt.show()

# %%
director_counts = data['Director'].value_counts()

# Create a new dataframe from the director counts
director_counts_df = pd.DataFrame({'Director': director_counts.index, 'Count': director_counts.values})
director_counts_df = director_counts_df.sort_values(by='Count', ascending=False)

# %%
import matplotlib.pyplot as plt
director_counts = data['Director'].value_counts()

director_counts_df = pd.DataFrame({'Director': director_counts.index, 'Count': director_counts.values})
director_counts_df = director_counts_df.sort_values(by='Count', ascending=False)
director_counts_df.plot(x='Director', y='Count', kind='bar', legend=False)

plt.xlabel('Director')
plt.ylabel('Count')
plt.title('Count of Movies/TV Shows Directed by Each Director')

# Show the plot
plt.show()

# %%
#summry
# Based on our analysis of the IMDB dataset, we found that [Genre Name] is the most popular genre among the top-rated movies and TV shows. Additionally, [Director Name] stands out as the director with the most top-rated productions. These insights can be valuable for understanding audience preferences and identifying successful directors in the industry.

# It's important to note that these findings are based on the specific IMDB dataset used for analysis. Further research and analysis can be conducted to validate these findings and explore additional insights.

# Overall, this analysis provides a glimpse into the popularity of different genres and the impact of directors in the realm of top-rated movies and TV shows.

# Feel free to expand upon this report with more detailed analysis, visualizations, and additional findings as per your specific analysis and dataset
